# %%
import numpy as np

from bs4 import BeautifulSoup
import requests

import os

from tqdm.notebook import tqdm
import pandas as pd
import re

import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, './script')
import medium

# %% [markdown]
# # Initialization

# %% [markdown]
# The __Medium__ class works with in a two-phases process.
# The two phases are called __First Extraction__ and __Second Extraction__.
#
# ### First Extraction
#
# First, the class goes to the link of the tag. In the following picture there is the exampke for the tag `okr`.

# %% [markdown]
# ![./figures/fig1.png](./figures/fig1.png)

# %% [markdown]
# This page shows _archive_, namely the dates where at least one article is published.
#
# ![fig2.png](./figures/fig2.png)

# %% [markdown]
# Then the method check for all the days where at least one article is found.
#
# ![fig3.png](./figures/fig3.png)
# ![fig4.png](./figures/fig4.png)

# %% [markdown]
# When initializing the class there is the need to specify the first year you want to start scraping the articles. In the case of `okr` we choose 2014.

# %%
ev = medium('okr',2014)
# Out:
# Checking archive...
# Checking year 2012...
# Checking year 2013...
# Checking year 2014...
# Checking year 2015...
# Checking year 2016...
# Checking year 2017...
# Checking year 2018...
# Checking year 2019...
# Checking year 2020...

# %% [markdown]
# In this first phase, a folder is created. The folder is stored in `./data/buffer/first_extraction`.
# In this folder are stored files for each day.
#
# ![fig5.png](./figures/fig5.png)

# %% [markdown]
# This is an example of file.
# ![fig6.png](./figures/fig6.png)

# %% [markdown]
# # Second Extraction

# %% [markdown]
# ### Articles dump
#
# For each of the files stored in the folder `./data/buffer/first_extraction` are downloaded the full page html and stored in a the folder `./data/buffer/second_extraction`.

# %% [markdown]
# ### Read html
#
# For each of the files stored in the folder `./data/buffer/second_extraction`, the html is scraped in order to extract the title, hyperlinks, tags and full content.

# %% [markdown]
# ##### The two phases are called by only one method

# %%
okr.extract_single_articles()
# Out:
# Dumping articles...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Reading html...
# HBox(children=(FloatProgress(value=0.0, max=1724.0), HTML(value='')))

# %% [markdown]
# #### See the data extracted

# %%
okr.data()
# Out:
# Data extracted
#       index                                           date  \
# 0         0  https://medium.com/tag/okr/archive/2018/10/02
# 1         0  https://medium.com/tag/okr/archive/2019/01/02
# 2         1  https://medium.com/tag/okr/archive/2019/01/02
# 3         2  https://medium.com/tag/okr/archive/2019/01/02
# 4         0  https://medium.com/tag/okr/archive/2018/11/26
# ...     ...                                            ...
# 1719      0  https://medium.com/tag/okr/archive/2018/12/26
# 1720      1  https://medium.com/tag/okr/archive/2018/12/26
# 1721      2  https://medium.com/tag/okr/archive/2018/12/26
# 1722      3  https://medium.com/tag/okr/archive/2018/12/26
# 1723      4  https://medium.com/tag/okr/archive/2018/12/26
#
#                                                   title  \
# 0                              OKRs — A Simple Template
# 1                 The Yearly Reflection Getaway Holiday
# 2     OKRs (Objective and Key Results) As A Primal B...
# 3     Confused about the difference between a priori...
# 4                                 ¡Hablemos en Números!
# ...                                                 ...
# 1719  New alternative to OKR’s, KRA’s & KPI’s for St...
# 1720                 The Common Mistakes in Writing OKR
# 1721        Personal Goal Setting & Living Deliberately
# 1722                                 Come 2019 (Part 2)
# 1723                                 Come 2019 (Part 3)
#
#                                                     url    pubDate  \
# 0     https://medium.com/@taratan/okrs-a-simple-temp... 2018-10-02
# 1     https://medium.com/@runetheill/the-yearly-refl... 2019-01-02
# 2     https://medium.com/@primalbranding/okrs-object... 2019-01-02
# 3     https://medium.com/@beckfeldt/confused-about-t... 2019-01-02
# 4     https://medium.com/@AndresERojasI/hablemos-en-... 2018-11-26
# ...                                                 ...        ...
# 1719  https://medium.com/@siddharthram/new-alternati... 2018-12-26
# 1720  https://medium.com/product-narrative/the-commo... 2018-12-26
# 1721  https://medium.com/@amamujee/personal-goal-set... 2018-12-26
# 1722  https://medium.com/the-learning-machine-projec... 2018-12-26
# 1723  https://medium.com/the-learning-machine-projec... 2018-12-26
#
#                  pubId                                            content  \
# 0      Y2018M10D2N0001  \n\nDespite its uncatchy moniker, OKRs (which ...
# 1       Y2019M1D2N0001  \n\nSince I decided to step up and take the le...
# 2       Y2019M1D2N0002  \n\nA friend handed me a copy of John Doerr’s ...
# 3       Y2019M1D2N0003  \n\nView original article on www.eckfeldt.com....
# 4     Y2018M11D26N0001  \n\n\begin_title\nCómo medir el éxito de tu Pr...
# ...                ...                                                ...
# 1719  Y2018M12D26N0001  \n\n\begin_title\nGoals, Methods, Habits for y...
# 1720  Y2018M12D26N0002  \n\nWelcome to Shared Narrative #11!\n\nOKR is...
# 1721  Y2018M12D26N0003  \n\nDecember 2018\n\nI wanted to share my pers...
# 1722  Y2018M12D26N0004  \n\n\begin_title\nOKRs and a Successful 2019\n...
# 1723  Y2018M12D26N0005  \n\n\begin_title\nOKRs and a Successful 2019\n...
#
#                                                    tags  \
# 0       Open in app; Okr; Startups; Productivity; Goals
# 1     Open in app; Okr; Reflections; Startup; CEO; M...
# 2     Open in app; Objective And Key Results; Primal...
# 3     Open in app; Okr; Priorities; Goals; Goal Sett...
# 4     Open in app; Startup; Kpi; Okr; Technology; Su...
# ...                                                 ...
# 1719  Open in app; Kpi; Startup; Entrepreneur; Produ...
# 1720  OKR; Our Newsletter; (in) Bahasa Indonesia; Ok...
# 1721                  Open in app; Goals; Planning; Okr
# 1722  Okr; Personal Development; Goals; Personal Gro...
# 1723  TLMP Updates; Okr; Self; Self Improvement; Per...
#
#                                                   links
# 0     http://tiny.cc/okr-template; /startup-tools/ok...
# 1     https://www.rockstart.com/; https://www.entrep...
# 2                                                   NaN
# 3     http://www.eckfeldt.com/blog-posts/confused-ab...
# 4                                                   NaN
# ...                                                 ...
# 1719  https://medium.com/u/67f5049293c7?source=post_...
# 1720  /product-narrative/the-trouble-two-challenges-...
# 1721  https://en.wikipedia.org/wiki/OKR; https://doc...
# 1722  /the-learning-machine-project/come-2019-part-1...
# 1723  /the-learning-machine-project/come-2019-part-1...
#
# [1724 rows x 9 columns]
